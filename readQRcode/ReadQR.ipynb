# %% [markdown]
# # <font style="color:rgb(50,120,229)">QR reader</font>
#
# Read an image that contains a QR code.
#
# The mandatory arguments are as follows.
# 1. `image`: Image on which the QR is to be found.
# 2. `pts`: Corners of the rectangle where the QR is found.

# %%
# Import cv2 module
import cv2

# Import matplotlib for displaying image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)

# %%
# Path to the image we are going to read
# This can be an absolute or relative path
# Here we are using a relative path
imageName = "info.jpg"

# Load the image
image = cv2.imread(imageName, cv2.IMREAD_COLOR)

# %%
# Display the original image
plt.imshow(image[:,:,::-1])

# %% [markdown]
# ### <font style="color:rgb(8,133,37)">Find the QR</font>
# Find the location of the code and the contents.

# %%
# Get an instance of QRCodeDetector, and run with our image
detector = cv2.QRCodeDetector()
decodedText, cornerPoints, _ = detector.detectAndDecode(image)

pt1 = (int(cornerPoints[0][0][0]), int(cornerPoints[0][0][1]))
pt2 = (int(cornerPoints[0][2][0]), int(cornerPoints[0][2][1]))

print(pt1)
# Out:
# (335, 332)

# %%
imageWithQR = image.copy()
#draw a rectangle around the QR code, if found

if cornerPoints is not None:
    # QR Code detected handling code
        print("QR code detected")
        print(decodedText)    
        cv2.rectangle(imageWithQR, (cornerPoints[0][0][0], cornerPoints[0][0][1]), (cornerPoints[0][2][0], cornerPoints[0][2][1]), (0, 255, 0), thickness=2, lineType=cv2.LINE_AA)
else:
        print("QR code not detected")
        #cv2.putText(imageWithQR, 'QR not found', cv2.FONT_HERSHEY_SIMPLEX, 1, (0,255,0), 2, cv2.LINE_AA)
# Out:
# QR code detected
# https://en.wikipedia.org/wiki/Main_Page
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[17], line 8
#       6         print("QR code detected")
#       7         print(decodedText)
# ----> 8         cv2.rectangle(imageWithQR, (cornerPoints[0][0][0], cornerPoints[0][0][1]), (cornerPoints[0][2][0], cornerPoints[0][2][1]), (0, 255, 0), thickness=2, lineType=cv2.LINE_AA);
#       9 else:
#      10         print("QR code not detected")
#
# error: OpenCV(4.10.0) :-1: error: (-5:Bad argument) in function 'rectangle'
# > Overload resolution failed:
# >  - Can't parse 'pt1'. Sequence item with index 0 has a wrong type
# >  - Can't parse 'pt1'. Sequence item with index 0 has a wrong type
# >  - argument for rectangle() given by name ('thickness') and position (4)
# >  - argument for rectangle() given by name ('thickness') and position (4)

# %%
# Display the image
plt.imshow(imageRectangle[:,:,::-1])
